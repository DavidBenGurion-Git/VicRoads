# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(16.7,13.27)})

# %%
lane3 = pd.read_csv("Lane3.csv")
lane3['Detector_Id'] = lane3['Detector_Id'].astype(str)

# %%
lane3 = lane3.drop(columns = ['ID', 'Date','Occupancy','Speed_Sum','Speed_Obs','Configuration_Id','Available','Incident','Failed'])

# %%
lane3.head()
# Out:
#       Time Detector_Id  Volume
# 0  7:45:00     1109523      12
# 1  7:45:20     1109523       6
# 2  7:45:40     1109523      12
# 3  7:46:00     1109523       5
# 4  7:46:20     1109523       4

# %%
data = pd.DataFrame({'X': lane3['Detector_Id'], 'Y': lane3['Time'], 'Z': lane3['Volume']})
data_pivoted = data.pivot("X", "Y", "Z")

data_pivoted.head(20)
# Out:
# Y        7:45:00  7:45:20  7:45:40  7:46:00  7:46:20  7:46:40  7:47:00  \
# X
# 1096951        6        8        8        7        5        4        6
# 1097029        3        6       10        7        7        4        4
# 1097045        3        4        5        8        9        5        4
# 1097062        5        1        5        8        7        9        3
# 1097079        5        5        2        5        8        6        8
# 1097100        5        7        6        4        5        6        7
# 1097116        9        5        5        7        6        6        4
# 1097140        6       11        7        3        7        5        5
# 1109523       12        6       12        5        4        7        7
#
# Y        7:47:20  7:47:40  7:48:00  ...  9:11:40  9:12:00  9:12:20  9:12:40  \
# X                                   ...
# 1096951        4        3        3  ...        3        2        6        5
# ...

# %%
ax = sns.heatmap(data_pivoted)
ax.set(xlabel='Time', ylabel='Detector ID', title='Lane3 Volume');
