# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(16.7,13.27)})

# %%
lane5 = pd.read_csv("Lane5.csv")
lane5['Detector_Id'] = lane5['Detector_Id'].astype(str)

# %%
lane5 = lane5.drop(columns = ['ID', 'Date','Occupancy','Speed_Sum','Speed_Obs','Configuration_Id','Available','Incident','Failed'])

# %%
lane5.head()
# Out:
#       Time Detector_Id  Volume
# 0  7:45:00     1097144       8
# 1  7:45:20     1097144       9
# 2  7:45:40     1097144       7
# 3  7:46:00     1097144       4
# 4  7:46:20     1097144       5

# %%
data = pd.DataFrame({'X': lane5['Detector_Id'], 'Y': lane5['Time'], 'Z': lane5['Volume']})
data_pivoted = data.pivot("X", "Y", "Z")

data_pivoted.head(20)
# Out:
# Y        7:45:00  7:45:20  7:45:40  7:46:00  7:46:20  7:46:40  7:47:00  \
# X
# 1097096        9        8        8        2        4       11        7
# 1097144        8        9        7        4        5        4        6
# 1108464        4        1        2        4        9        5        4
# 1108471        7        4       12       10       11        5        6
# 1108480        8        6        6        8        2        5       11
# 1109515        5        7        0        2        7        7        6
# 1109704       10        6        6        4        7        4        6
# 1110858        2        9       13       10        6        8        5
#
# Y        7:47:20  7:47:40  7:48:00  ...  9:11:40  9:12:00  9:12:20  9:12:40  \
# X                                   ...
# 1097096        9        6        8  ...        6        7        4        1
# 1097144        9        7        9  ...        2        1        6        4
# ...

# %%
df2= data_pivoted.reindex(['1109704','1110858','1108471','1108464','1109515','1097096','1108480','1097144'])

# %%
ax = sns.heatmap(df2)
ax.set(xlabel='Time', ylabel='Detector ID', title='Lane5 Volume');
