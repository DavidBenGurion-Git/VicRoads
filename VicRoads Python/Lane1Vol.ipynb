# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(16.7,13.27)})

# %%
lane1 = pd.read_csv("Lane1.csv")
lane1['Detector_Id'] = lane1['Detector_Id'].astype(str)

# %%
lane1 = lane1.drop(columns = ['ID', 'Date','Occupancy','Speed_Sum','Speed_Obs','Configuration_Id','Available','Incident','Failed'])

# %%
lane1.head()
# Out:
#       Time Detector_Id  Volume
# 0  7:45:00     1109519       6
# 1  7:45:20     1109519       7
# 2  7:45:40     1109519       8
# 3  7:46:00     1109519       1
# 4  7:46:20     1109519       2

# %%
data = pd.DataFrame({'X': lane1['Detector_Id'], 'Y': lane1['Time'], 'Z': lane1['Volume']})
data_pivoted = data.pivot("X", "Y", "Z")

data_pivoted.head(20)
# Out:
# Y        7:45:00  7:45:20  7:45:40  7:46:00  7:46:20  7:46:40  7:47:00  \
# X
# 1096944        7        8        3        8        2        6        3
# 1097025        5        4        7        4        7        3        6
# 1097041        3        6        3        7        7        5        2
# 1097058        3        3        4        8        1        8        4
# 1097075        3        3        3        2        4        2        8
# 1097112        7        4        3        2        2        6        3
# 1097136        6        8        3        2        3        4        3
# 1109519        6        7        8        1        2        3        3
# 1109577        3        2        3        3        3        3        1
#
# Y        7:47:20  7:47:40  7:48:00  ...  9:11:40  9:12:00  9:12:20  9:12:40  \
# X                                   ...
# 1096944        0        6        5  ...        3        0        1        1
# ...

# %%
df2= data_pivoted.reindex(['1096944','1097025','1097041','1097058','1097075','1109577','1097112','1097136','1109519'])

# %%
ax = sns.heatmap(df2)
ax.set(xlabel='Time', ylabel='Detector ID', title='Lane1 Volume');
