# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(16.7,13.27)})

# %%
lane2 = pd.read_csv("Lane2.csv")
lane2['Detector_Id'] = lane2['Detector_Id'].astype(str)

# %%
lane2 = lane2.drop(columns = ['ID', 'Date','Volume','Speed_Sum','Speed_Obs','Configuration_Id','Available','Incident','Failed'])

# %%
lane2.head()
# Out:
#       Time Detector_Id  Occupancy
# 0  7:45:00     1109521         61
# 1  7:45:20     1109521        125
# 2  7:45:40     1109521         74
# 3  7:46:00     1109521         79
# 4  7:46:20     1109521         49

# %%
data = pd.DataFrame({'X': lane2['Detector_Id'], 'Y': lane2['Time'], 'Z': lane2['Occupancy']})
data_pivoted = data.pivot("X", "Y", "Z")

# %%
ax = sns.heatmap(data_pivoted)
ax.set(xlabel='Time', ylabel='Detector ID', title='Lane2 Occupancy');
