# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(16.7,13.27)})

# %%
lane4 = pd.read_csv("Lane4.csv")
lane4['Detector_Id'] = lane4['Detector_Id'].astype(str)

# %%
lane4 = lane4.drop(columns = ['ID', 'Date','Volume','Speed_Sum','Speed_Obs','Configuration_Id','Available','Incident','Failed'])

# %%
lane4.head()
# Out:
#       Time Detector_Id  Occupancy
# 0  7:45:00     1109525         27
# 1  7:45:20     1109525         58
# 2  7:45:40     1109525         62
# 3  7:46:00     1109525         52
# 4  7:46:20     1109525         35

# %%
data = pd.DataFrame({'X': lane4['Detector_Id'], 'Y': lane4['Time'], 'Z': lane4['Occupancy']})
data_pivoted = data.pivot("X", "Y", "Z")

# %%
ax = sns.heatmap(data_pivoted)
ax.set(xlabel='Time', ylabel='Detector ID', title='Lane4 Occupancy');
